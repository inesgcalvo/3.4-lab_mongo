# %% [markdown]
# # Advanced Querying Mongo

# %% [markdown]
# Importing libraries and setting up connection

# %%
# %pip install pymongo

# %%
from pymongo import MongoClient
import pandas as pd

# %%
cursor = MongoClient('mongodb://localhost:27017')

# %%
cursor.list_database_names()
# Out:
# ['admin', 'companies', 'config', 'local']

# %%
db = cursor.companies

# %%
colec = db.coleccion

# %% [markdown]
# ### 1. All the companies whose name match 'Babelgum'. Retrieve only their `name` field.

# %%
query = {'name': 'Babelgum'}

select = {'_id': False, 'name': True}

list(colec.find(query, select))
# Out:
# [{'name': 'Babelgum'}]

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
query = {'number_of_employees': {'$gt': 5000}}

select = {'_id': False}

pd.DataFrame(colec.find(query, select).sort('number_of_employees', -1).limit(20)).head(2)
# Out:
#       name permalink                             crunchbase_url  \
# 0  Siemens   siemens  http://www.crunchbase.com/company/siemens
# 1      IBM       ibm      http://www.crunchbase.com/company/ibm
#
#              homepage_url blog_url blog_feed_url twitter_username  \
# 0  http://www.siemens.com                                 Siemens
# 1      http://www.ibm.com                                     IBM
#
#   category_code  number_of_employees  founded_year  ...  \
# 0      hardware               405000        1847.0  ...
# 1      software               388000        1896.0  ...
#
#                                          investments  acquisition  \
# 0                                                 []         None
# 1  [{'funding_round': {'round_code': 'c', 'source...         None
#
#                                         acquisitions  \
# 0  [{'price_amount': 418000000, 'price_currency_c...
# 1  [{'price_amount': None, 'price_currency_code':...
#
#                                              offices  \
# 0  [{'description': '', 'address1': 'Wittelsbache...
# 1  [{'description': 'Corporate Headquarters', 'ad...
#
#                                           milestones  \
# 0  [{'id': 35852, 'description': 'Siemens Receive...
# 1  [{'id': 10471, 'description': 'IBM Completes A...
#
#                                                  ipo  \
# 0  {'valuation_amount': None, 'valuation_currency...
# 1  {'valuation_amount': None, 'valuation_currency...
#
#                                         video_embeds  \
# 0  [{'embed_code': '<iframe width="420" height="3...
# 1  [{'embed_code': '<embed src="http://blip.tv/pl...
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[150, 92], 'assets/imag...
# 1  [{'available_sizes': [[[150, 93], 'assets/imag...
#
#                                       external_links partners
# 0                                                 []       []
# 1  [{'external_url': 'http://mashpedia.com/IBM', ...       []
#
# [2 rows x 41 columns]

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fields.

# %%
# query = {'$and': [{'founded_year': {'$gte': 2000}}, {'founded_year': {'$lte': 2005}}]}

query = {'founded_year': {'$gte': 2000, '$lte': 2005}}

select = {'_id': False, 'name': True, 'founded_year': True}

pd.DataFrame(colec.find(query, select)).head()
# Out:
#         name  founded_year
# 0   Wetpaint          2005
# 1       Zoho          2005
# 2       Digg          2004
# 3   Facebook          2004
# 4  Omnidrive          2005

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
query = {'$and': [{'ipo.valuation_amount': {'$gt': 100_000_000}},
                  {'founded_year': {'$lt': 2010}}]}

select = {'_id': False, 'name': True, 'ipo': True}

pd.DataFrame(colec.find(query, select)).head()
# Out:
#        name                                                ipo
# 0  Facebook  {'valuation_amount': 104000000000.0, 'valuatio...
# 1   Twitter  {'valuation_amount': 18100000000.0, 'valuation...
# 2      Yelp  {'valuation_amount': 1300000000, 'valuation_cu...
# 3  LinkedIn  {'valuation_amount': 9310000000.0, 'valuation_...
# 4    Amazon  {'valuation_amount': 100000000000.0, 'valuatio...

# %%
10000000 == 10_000_000
# Out:
# True

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
query = {'$and': [{'number_of_employees': {'$lt': 1000}},
                  {'founded_year': {'$lt': 2005}}]}

select = {'_id': False}

pd.DataFrame(colec.find(query, select).sort('number_of_employees', -1).limit(10)).head(2)
# Out:
#                               name                        permalink  \
# 0             Infinera Corporation                         infinera
# 1  NorthPoint Communications Group  northpoint-communications-group
#
#                                       crunchbase_url             homepage_url  \
# 0         http://www.crunchbase.com/company/infinera  http://www.infinera.com
# 1  http://www.crunchbase.com/company/northpoint-c...
#
#   blog_url blog_feed_url twitter_username    category_code  \
# 0                            InfineraCorp  network_hosting
# 1                                          network_hosting
#
#    number_of_employees  founded_year  ...  investments  acquisition  \
# 0                  974          2000  ...           []         None
# 1                  948          1997  ...           []         None
#
#   acquisitions                                            offices  \
# 0           []  [{'description': 'Headquarters', 'address1': '...
# 1           []  [{'description': 'HQ', 'address1': '303 Second...
#
#                                           milestones  \
# 0  [{'id': 20267, 'description': 'Infinera PICs S...
# 1                                                 []
#
#                                                  ipo video_embeds  \
# 0  {'valuation_amount': None, 'valuation_currency...           []
# 1                                               None           []
#
#                                          screenshots external_links partners
# 0  [{'available_sizes': [[[150, 112], 'assets/ima...             []       []
# 1                                                 []             []       []
#
# [2 rows x 41 columns]

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
query = {'partners': []}

select = {'_id': False}

pd.DataFrame(colec.find(query, select)).head(2)
# Out:
#         name permalink                               crunchbase_url  \
# 0   Wetpaint      abc2   http://www.crunchbase.com/company/wetpaint
# 1  AdventNet      abc3  http://www.crunchbase.com/company/adventnet
#
#               homepage_url                     blog_url  \
# 0  http://wetpaint-inc.com  http://digitalquarters.net/
# 1     http://adventnet.com
#
#                       blog_feed_url twitter_username category_code  \
# 0  http://digitalquarters.net/feed/  BachelrWetpaint           web
# 1                                       manageengine    enterprise
#
#    number_of_employees  founded_year  ...  \
# 0                 47.0        2005.0  ...
# 1                600.0        1996.0  ...
#
#                                              offices  \
# 0  [{'description': '', 'address1': '710 - 2nd Av...
# 1  [{'description': 'Headquarters', 'address1': '...
#
#                                           milestones  video_embeds  \
# 0  [{'id': 5869, 'description': 'Wetpaint named i...            []
# 1                                                 []            []
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[150, 86], 'assets/imag...
# 1  [{'available_sizes': [[[150, 94], 'assets/imag...
#
#                                       external_links partners  \
# 0  [{'external_url': 'http://www.geekwire.com/201...       []
# 1                                                 []       []
#
#   deadpooled_month deadpooled_day deadpooled_url  ipo
# 0              NaN            NaN            NaN  NaN
# 1              NaN            NaN            NaN  NaN
#
# [2 rows x 41 columns]

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
query = {'category_code': None}

select = {'_id': False}

pd.DataFrame(colec.find(query, select)).head(2)
# Out:
#          name   permalink                                crunchbase_url  \
# 0  Collective  collective  http://www.crunchbase.com/company/collective
# 1     Snimmer     snimmer     http://www.crunchbase.com/company/snimmer
#
#   homepage_url blog_url blog_feed_url twitter_username category_code  \
# 0         None     None          None             None          None
# 1         None     None          None             None          None
#
#    number_of_employees  founded_year  ...  investments  acquisition  \
# 0                  NaN           NaN  ...           []         None
# 1                  NaN           NaN  ...           []         None
#
#    acquisitions  offices  milestones   ipo video_embeds screenshots  \
# 0            []       []          []  None           []          []
# 1            []       []          []  None           []          []
#
#   external_links partners
# 0             []       []
# 1             []       []
#
# [2 rows x 41 columns]

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
# query = {'$and': [{'number_of_employees': {'$gt': 100}}, {'number_of_employees': {'$lt': 1000}}]}

query = {'number_of_employees': {'$gte': 100, '$lt': 1000}}

select = {'_id': False, 'name': True, 'number_of_employees': True}

pd.DataFrame(colec.find(query, select)).head()
# Out:
#         name  number_of_employees
# 0  AdventNet                  600
# 1    AddThis                  120
# 2      OpenX                  305
# 3   LifeLock                  644
# 4      Jajah                  110

# %% [markdown]
# ### 9. Order all the companies by their IPO price in a descending order.

# %%
query = {'ipo': {'$ne': {}}}

select = {'_id': False}

pd.DataFrame(colec.find(query, select).sort('ipo.valuation_amount', -1)).head(2)
# Out:
#        name permalink                              crunchbase_url  \
# 0      GREE      gree      http://www.crunchbase.com/company/gree
# 1  Facebook  facebook  http://www.crunchbase.com/company/facebook
#
#                homepage_url                  blog_url  \
# 0  http://www.gree-corp.com
# 1       http://facebook.com  http://blog.facebook.com
#
#                        blog_feed_url twitter_username category_code  \
# 0                                           gree_corp   games_video
# 1  http://blog.facebook.com/atom.php         facebook        social
#
#    number_of_employees  founded_year  ...  \
# 0                700.0        2004.0  ...
# 1               5299.0        2004.0  ...
#
#                                          investments  acquisition  \
# 0  [{'funding_round': {'round_code': 'seed', 'sou...         None
# 1  [{'funding_round': {'round_code': 'seed', 'sou...         None
#
#                                         acquisitions  \
# 0  [{'price_amount': 104000000, 'price_currency_c...
# 1  [{'price_amount': None, 'price_currency_code':...
#
#                                              offices  \
# 0  [{'description': 'Headquarters', 'address1': '...
# 1  [{'description': 'Headquarters', 'address1': '...
#
#                                           milestones  \
# 0  [{'id': 1021, 'description': 'IPO', 'stoned_ye...
# 1  [{'id': 108, 'description': 'Facebook adds com...
#
#                                                  ipo video_embeds  \
# 0  {'valuation_amount': 108960000000.0, 'valuatio...           []
# 1  {'valuation_amount': 104000000000.0, 'valuatio...           []
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[133, 150], 'assets/ima...
# 1  [{'available_sizes': [[[150, 68], 'assets/imag...
#
#                                       external_links partners
# 0                                                 []       []
# 1  [{'external_url': 'http://latimesblogs.latimes...       []
#
# [2 rows x 41 columns]

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
query = {'number_of_employees': {'$gt': 100000}}

select = {'_id': False}

pd.DataFrame(colec.find(query, select).sort('number_of_employees', -1).limit(10)).head(2)
# Out:
#       name permalink                             crunchbase_url  \
# 0  Siemens   siemens  http://www.crunchbase.com/company/siemens
# 1      IBM       ibm      http://www.crunchbase.com/company/ibm
#
#              homepage_url blog_url blog_feed_url twitter_username  \
# 0  http://www.siemens.com                                 Siemens
# 1      http://www.ibm.com                                     IBM
#
#   category_code  number_of_employees  founded_year  ...  \
# 0      hardware               405000          1847  ...
# 1      software               388000          1896  ...
#
#                                          investments  acquisition  \
# 0                                                 []         None
# 1  [{'funding_round': {'round_code': 'c', 'source...         None
#
#                                         acquisitions  \
# 0  [{'price_amount': 418000000, 'price_currency_c...
# 1  [{'price_amount': None, 'price_currency_code':...
#
#                                              offices  \
# 0  [{'description': '', 'address1': 'Wittelsbache...
# 1  [{'description': 'Corporate Headquarters', 'ad...
#
#                                           milestones  \
# 0  [{'id': 35852, 'description': 'Siemens Receive...
# 1  [{'id': 10471, 'description': 'IBM Completes A...
#
#                                                  ipo  \
# 0  {'valuation_amount': None, 'valuation_currency...
# 1  {'valuation_amount': None, 'valuation_currency...
#
#                                         video_embeds  \
# 0  [{'embed_code': '<iframe width="420" height="3...
# 1  [{'embed_code': '<embed src="http://blip.tv/pl...
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[150, 92], 'assets/imag...
# 1  [{'available_sizes': [[[150, 93], 'assets/imag...
#
#                                       external_links partners
# 0                                                 []       []
# 1  [{'external_url': 'http://mashpedia.com/IBM', ...       []
#
# [2 rows x 41 columns]

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
query = {'founded_month': {'$gt': 6}}

select = {'_id': False}

pd.DataFrame(colec.find(query, select).limit(1000)).head(2)
# Out:
#        name permalink                              crunchbase_url  \
# 0  Wetpaint      abc2  http://www.crunchbase.com/company/wetpaint
# 1      Zoho      abc4      http://www.crunchbase.com/company/zoho
#
#               homepage_url                     blog_url  \
# 0  http://wetpaint-inc.com  http://digitalquarters.net/
# 1          http://zoho.com       http://blogs.zoho.com/
#
#                       blog_feed_url twitter_username category_code  \
# 0  http://digitalquarters.net/feed/  BachelrWetpaint           web
# 1        http://blogs.zoho.com/feed             zoho      software
#
#    number_of_employees  founded_year  ...  \
# 0                 47.0          2005  ...
# 1               1600.0          2005  ...
#
#                                              offices  \
# 0  [{'description': '', 'address1': '710 - 2nd Av...
# 1  [{'description': 'Headquarters', 'address1': '...
#
#                                           milestones  \
# 0  [{'id': 5869, 'description': 'Wetpaint named i...
# 1  [{'id': 388, 'description': 'Zoho Reaches 2 Mi...
#
#                                         video_embeds  \
# 0                                                 []
# 1  [{'embed_code': '<object width="430" height="2...
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[150, 86], 'assets/imag...
# 1                                                 []
#
#                                       external_links partners  \
# 0  [{'external_url': 'http://www.geekwire.com/201...       []
# 1  [{'external_url': 'http://www.online-tech-tips...       []
#
#   deadpooled_month deadpooled_day deadpooled_url  ipo
# 0              NaN            NaN            NaN  NaN
# 1              NaN            NaN            NaN  NaN
#
# [2 rows x 41 columns]

# %% [markdown]
# ### 12. All the companies founded before 2000 that have an acquisition amount of more than 10.000.00

# %%
query = {'$and': [{'acquisition.price_amount': {'$gt': 10_000_000}},
                  {'founded_year': {'$lt': 2000}}]}

select = {'_id': False}

pd.DataFrame(colec.find(query, select)).head(2)
# Out:
#        name permalink                              crunchbase_url  \
# 0   Postini   postini   http://www.crunchbase.com/company/postini
# 1  SideStep  sidestep  http://www.crunchbase.com/company/sidestep
#
#               homepage_url blog_url blog_feed_url twitter_username  \
# 0       http://postini.com                                    None
# 1  http://www.sidestep.com     None          None             None
#
#   category_code  number_of_employees  founded_year  ...  investments  \
# 0           web                  NaN          1999  ...           []
# 1           web                 75.0          1999  ...           []
#
#                                          acquisition  acquisitions  \
# 0  {'price_amount': 625000000, 'price_currency_co...            []
# 1  {'price_amount': 180000000, 'price_currency_co...            []
#
#                                              offices  milestones   ipo  \
# 0  [{'description': None, 'address1': '959 Skyway...          []  None
# 1  [{'description': None, 'address1': '2980 Bower...          []  None
#
#   video_embeds screenshots external_links partners
# 0           []          []             []       []
# 1           []          []             []       []
#
# [2 rows x 41 columns]

# %% [markdown]
# ### 13. All the companies that have been acquired after 2010, order by the acquisition amount, and retrieve only their `name` and `acquisition` field.

# %%
query = {'acquisition.acquired_year': {'$gt': 2010}}

select = {'_id': False, 'name': True, 'acquisition': True}

pd.DataFrame(colec.find(query, select).sort('acquisition.price_amount', -1)).head()
# Out:
#                      name                                        acquisition
# 0                T-Mobile  {'price_amount': 39000000000.0, 'price_currenc...
# 1    Goodrich Corporation  {'price_amount': 18400000000.0, 'price_currenc...
# 2                     LSI  {'price_amount': 6600000000.0, 'price_currency...
# 3  National Semiconductor  {'price_amount': 6500000000.0, 'price_currency...
# 4                   Ariba  {'price_amount': 4300000000.0, 'price_currency...

# %% [markdown]
# ### 14. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
query = {'founded_year': {'$ne': None}}

select = {'_id': False, 'name': True, 'founded_year': True}

pd.DataFrame(colec.find(query, select).sort('founded_year', 1)).head()
# Out:
#           name  founded_year
# 0   Alstrasoft          1800
# 1  SmallWorlds          1800
# 2      US Army          1800
# 3       DuPont          1802
# 4     McKesson          1833

# %% [markdown]
# ### 15. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `acquisition price` in a descending order. Limit the search to 10 documents.

# %%
query = {'founded_day': {'$lte': 7}}

select = {'_id': False}

pd.DataFrame(colec.find(query, select).sort('acquisition.price_amount', -1).limit(10)).head(2)
# Out:
#        name permalink                              crunchbase_url  \
# 0  Netscape  netscape  http://www.crunchbase.com/company/netscape
# 1    PayPal    paypal    http://www.crunchbase.com/company/paypal
#
#               homepage_url blog_url blog_feed_url twitter_username  \
# 0  http://netscape.aol.com
# 1    http://www.paypal.com                                  paypal
#
#   category_code  number_of_employees  founded_year  ...  \
# 0      software                  NaN          1994  ...
# 1       finance             300000.0          1998  ...
#
#                                          investments  \
# 0                                                 []
# 1  [{'funding_round': {'round_code': 'c', 'source...
#
#                                          acquisition  \
# 0  {'price_amount': 4200000000.0, 'price_currency...
# 1  {'price_amount': 1500000000, 'price_currency_c...
#
#                                         acquisitions  \
# 0                                                 []
# 1  [{'price_amount': None, 'price_currency_code':...
#
#                                              offices  \
# 0  [{'description': '', 'address1': '466 Ellis St...
# 1  [{'description': '', 'address1': '2145 E Hamil...
#
#                                           milestones   ipo video_embeds  \
# 0                                                 []  None           []
# 1  [{'id': 11916, 'description': 'Reserve Bank Of...  None           []
#
#                                          screenshots  \
# 0                                                 []
# 1  [{'available_sizes': [[[150, 120], 'assets/ima...
#
#                                       external_links partners
# 0                                                 []       []
# 1  [{'external_url': 'http://www.sociableblog.com...       []
#
# [2 rows x 41 columns]

# %% [markdown]
# ### 16. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascending order.

# %%
query = {'$and': [{'category_code': 'web'},
                  {'number_of_employees': {'$gt': 4000}}]}

select = {'_id': False}

pd.DataFrame(colec.find(query, select).sort('number_of_employees', 1)).head(2)
# Out:
#       name permalink                             crunchbase_url  \
# 0  Expedia   expedia  http://www.crunchbase.com/company/expedia
# 1      AOL       aol      http://www.crunchbase.com/company/aol
#
#              homepage_url              blog_url  \
# 0  http://www.expedia.com
# 1      http://www.aol.com  http://blog.aol.com/
#
#                                     blog_feed_url twitter_username  \
# 0                                                          Expedia
# 1  http://feeds.feedburner.com/AolBlog?format=xml              aol
#
#   category_code  number_of_employees  founded_year  ...  \
# 0           web                 4400          1996  ...
# 1           web                 8000          1985  ...
#
#                                          investments  \
# 0  [{'funding_round': {'round_code': 'c', 'source...
# 1  [{'funding_round': {'round_code': 'b', 'source...
#
#                                          acquisition  \
# 0  {'price_amount': None, 'price_currency_code': ...
# 1                                               None
#
#                                         acquisitions  \
# 0  [{'price_amount': None, 'price_currency_code':...
# 1  [{'price_amount': 40000000, 'price_currency_co...
#
#                                              offices  \
# 0  [{'description': 'Corporate Office', 'address1...
# 1  [{'description': 'HQ', 'address1': '770 Broadw...
#
#                                           milestones  \
# 0  [{'id': 11691, 'description': 'US AIRWAYS AND ...
# 1  [{'id': 2689, 'description': 'AOL relauches, c...
#
#                                                  ipo  \
# 0  {'valuation_amount': None, 'valuation_currency...
# 1  {'valuation_amount': None, 'valuation_currency...
#
#                                         video_embeds  \
# 0                                                 []
# 1  [{'embed_code': '<embed src="http://blip.tv/pl...
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[150, 93], 'assets/imag...
# 1  [{'available_sizes': [[[150, 91], 'assets/imag...
#
#                                       external_links partners
# 0  [{'external_url': 'http://www.urlaubs-rabatte....       []
# 1  [{'external_url': 'http://mashpedia.com/AOL', ...       []
#
# [2 rows x 41 columns]

# %% [markdown]
# ### 17. All the companies whose acquisition amount is more than 10.000.000, and currency is 'EUR'.

# %%
query = {'$and': [
        
        {'$or': [{'acquisition.price_currency_code': 'eur'},
                 {'acquisition.price_currency_code': 'EUR'}]},
        {'acquisition.price_amount': {'$gt': 10_000_000}}]}

select = {'_id': False}

pd.DataFrame(colec.find(query, select)).head(2)
# Out:
#       name permalink                             crunchbase_url  \
# 0      ZYB       zyb      http://www.crunchbase.com/company/zyb
# 1  Apertio   apertio  http://www.crunchbase.com/company/apertio
#
#              homepage_url              blog_url  \
# 0          http://zyb.com  http://blog.zyb.com/
# 1  http://www.apertio.com
#
#                          blog_feed_url twitter_username category_code  \
# 0  http://blog.zyb.com/index.php/feed/             None        mobile
# 1                                                  None        mobile
#
#    number_of_employees  founded_year  ...  investments  \
# 0                 25.0           NaN  ...           []
# 1                  NaN           NaN  ...           []
#
#                                          acquisition  \
# 0  {'price_amount': 31500000, 'price_currency_cod...
# 1  {'price_amount': 140000000, 'price_currency_co...
#
#                                         acquisitions  \
# 0  [{'price_amount': None, 'price_currency_code':...
# 1                                                 []
#
#                                              offices milestones   ipo  \
# 0  [{'description': None, 'address1': 'Esromgade ...         []  None
# 1  [{'description': None, 'address1': '', 'addres...         []  None
#
#   video_embeds screenshots external_links partners
# 0           []          []             []       []
# 1           []          []             []       []
#
# [2 rows x 41 columns]

# %% [markdown]
# ### 18. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
query = {'acquisition.acquired_month': {'$lt': 4}}

select = {'_id': False, 'name': True, 'acquisition': True}

pd.DataFrame(colec.find(query, select).limit(10))
# Out:
#           name                                        acquisition
# 0         Kyte  {'price_amount': None, 'price_currency_code': ...
# 1   NetRatings  {'price_amount': 327000000, 'price_currency_co...
# 2       blogTV  {'price_amount': None, 'price_currency_code': ...
# 3   Livestream  {'price_amount': None, 'price_currency_code': ...
# 4     iContact  {'price_amount': 169000000, 'price_currency_co...
# 5      Coghead  {'price_amount': None, 'price_currency_code': ...
# 6  Dailymotion  {'price_amount': 168000000, 'price_currency_co...
# 7     Netvibes  {'price_amount': None, 'price_currency_code': ...
# 8       Flickr  {'price_amount': None, 'price_currency_code': ...
# 9   BabyCenter  {'price_amount': None, 'price_currency_code': ...

# %% [markdown]
# # Bonus
# ### 19. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
query = {'$and': [{'founded_year': {'$gte': 2000, '$lte': 2010}},
                 {'acquisition.acquired_year': {'$gte': 2011}}]}

select = {'_id': False}

pd.DataFrame(colec.find(query, select)).head(2)
# Out:
#        name permalink                              crunchbase_url  \
# 0  Wetpaint      abc2  http://www.crunchbase.com/company/wetpaint
# 1      Digg      digg      http://www.crunchbase.com/company/digg
#
#               homepage_url                     blog_url  \
# 0  http://wetpaint-inc.com  http://digitalquarters.net/
# 1      http://www.digg.com        http://blog.digg.com/
#
#                       blog_feed_url twitter_username category_code  \
# 0  http://digitalquarters.net/feed/  BachelrWetpaint           web
# 1   http://blog.digg.com/?feed=rss2             digg          news
#
#    number_of_employees  founded_year  ...  \
# 0                 47.0          2005  ...
# 1                 60.0          2004  ...
#
#                                              offices  \
# 0  [{'description': '', 'address1': '710 - 2nd Av...
# 1  [{'description': None, 'address1': '135 Missis...
#
#                                           milestones  \
# 0  [{'id': 5869, 'description': 'Wetpaint named i...
# 1  [{'id': 9588, 'description': 'Another Digg Exe...
#
#                                         video_embeds  \
# 0                                                 []
# 1  [{'embed_code': '<embed src="http://blip.tv/pl...
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[150, 86], 'assets/imag...
# 1  [{'available_sizes': [[[117, 150], 'assets/ima...
#
#                                       external_links partners  \
# 0  [{'external_url': 'http://www.geekwire.com/201...       []
# 1  [{'external_url': 'http://www.sociableblog.com...       []
#
#   deadpooled_month deadpooled_day deadpooled_url   ipo
# 0              NaN            NaN            NaN   NaN
# 1              NaN            NaN           None  None
#
# [2 rows x 41 columns]

# %% [markdown]
# ### 20. All the companies that have been 'deadpooled' after the third year.

# %%
query ={'$and': [{'$expr': {'$gt': ['$deadpooled_year', {'$add': ['$founded_year', 3]}
                                   ]
                           }
                 },
                {'founded_year': {'$ne': None}},
                {'deadpooled_year': {'$ne': None, '$gt': 1800}}]}

select = {'_id': False}

pd.DataFrame(colec.find(query, select)).head(2)
# Out:
#        name permalink                              crunchbase_url  \
# 0  Babelgum  babelgum  http://www.crunchbase.com/company/babelgum
# 1     Thoof     thoof     http://www.crunchbase.com/company/thoof
#
#           homepage_url                  blog_url  \
# 0  http://babelgum.com  http://babelgum.com/blog
# 1     http://thoof.com
#
#                           blog_feed_url twitter_username category_code  \
# 0  http://feeds.feedburner.com/Babelgum         Babelgum   games_video
# 1                                  None             None           web
#
#    number_of_employees  founded_year  ...  investments  acquisition  \
# 0                  NaN          2007  ...           []         None
# 1                  NaN          2006  ...           []         None
#
#    acquisitions                                            offices  \
# 0            []  [{'description': '', 'address1': '', 'address2...
# 1            []  [{'description': None, 'address1': None, 'addr...
#
#    milestones   ipo video_embeds screenshots  \
# 0          []  None           []          []
# 1          []  None           []          []
#
#                                       external_links partners
# 0                                                 []       []
# 1  [{'external_url': 'http://www.duraslide.com.sg...       []
#
# [2 rows x 41 columns]
